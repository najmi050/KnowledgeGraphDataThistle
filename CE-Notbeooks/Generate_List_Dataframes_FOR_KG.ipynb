# %% [markdown]
# ## Generating the LIST Dataframes FOR THE KG
#
#
# In this notebook we are going to generate and save (into disk) a dataframe per CE ontology NODE.
# This is the list of the dataframes saved to file. These dataframes have **ONLY the necessary attributes for later generating the graph, and linking the information between nodes**:
#
# - df_events
# - df_event_category
# - df_event_tags
# - df_event_description
# - df_event_properties
# - df_event_phonenumber
#
# - df_schedules
# - df_schedules_phone_numbers
#
# - df_performances
# - df_performances_properties
# - df_performances_descriptions
# - df_performances_links
#
# - df_tickets
#
# - df_places
# - df_places_tags
# - df_places_properties
# - df_places_description
# - df_places_loc
# - df_places_pn
#
#
#
# We are also generating another intermediate dataframes (those dataframes have 'total' in their names). But those intermediate dataframes will not be saved to disk.
#
# The idea will be later to read from those dataframes saved to disk to create the knowledge graph.
#
# In order to create these, we are going to use two dataframes previously calculated:
#  - df_news_events
#  - df_places

# %%
import yaml
import string
import copy
from datetime import datetime
import pandas as pd
from yaml import safe_load
from pandas.io.json import json_normalize
from difflib import SequenceMatcher
import pickle
import numpy as np
import collections
from yaml import safe_load

# %% [markdown]
# We are going to save the dataframes in a directory called dataframes_final

# %%
# !mkdir /content/drive/MyDrive/dataframes_final
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/dataframes_final’: No such file or directory

# %%
dataframes_final="/content/drive/MyDrive/dataframes_final"

# %% [markdown]
# ## 1. EVENTS DATAFRAME
#
# Going to read the events dataframe and work with it.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.listdir("/content/drive/MyDrive")

# %%
with open("/content/drive/MyDrive/df_new_events","rb") as df_new_events:
    df_new_events=pickle.load(df_new_events)

# %%
df_new_events.iloc[0]

# %%
df_events=df_new_events[['event_id','id', 'name', 'created_ts', 'modified_ts','website', 'ranking_in_level', 'ranking_level', 'sort_name', 'status']]

# %% [markdown]
# **Important** Use this dataframe for reading the properties of events in your knowlege graph. Not the df_new_events

# %%
df_events.to_pickle(dataframes_final+"/df_events")

# %% [markdown]
# ## 2. EVENTS_DESCRIPTION DATAFRAME

# %%
df_new_events['descriptions']
# Out:
# 0       [{'type': 'description.list.default', 'descrip...
# 1       [{'type': 'description.list.default', 'descrip...
# 2       [{'type': 'description.list.default', 'descrip...
# 3       [{'type': 'description.list.default', 'descrip...
# 4       [{'type': 'description.list.default', 'descrip...
#                               ...
# 2272    [{'type': 'description.list.default', 'descrip...
# 2276    [{'type': 'description.list.default', 'descrip...
# 2278    [{'type': 'description.official', 'description...
# 2279    [{'type': 'description.list.default', 'descrip...
# 2280    [{'type': 'description.list.default', 'descrip...
# Name: descriptions, Length: 38700, dtype: object

# %%
df_e_desc=df_new_events[['event_id','descriptions']].explode('descriptions')
df_e_desc=df_e_desc[df_e_desc['descriptions'].notna()]
df_e_desc=pd.concat([df_e_desc.drop(['descriptions'], axis=1), df_e_desc['descriptions'].apply(pd.Series)], axis=1)
#df_e_desc=df_e_desc.drop(0, axis=1)
df_e_desc
# Out:
#       event_id                      type  \
# 0       157884  description.list.default
# 1       194419  description.list.default
# 1       194419      description.official
# 2       240818  description.list.default
# 3       345866  description.list.default
# ...        ...                       ...
# 2276   1586592  description.list.default
# 2278   1595055      description.official
# 2278   1595055  description.list.default
# 2279   1599103  description.list.default
# 2280   1603922  description.list.default
#
#                                             description
# 0     Swedish trio combining acoustic instrumentatio...
# 1     Brilliant mix of English tradition and America...
# 1     Nominated for Musician of the Year and for Bes...
# 2     Robbie Burns was funny, right? So toast the ba...
# 3     The Stand's spankingly good new talent night, ...
# ...                                                 ...
# 2276  Tour starting at Edinburgh's The Elephant Hous...
# 2278  The tour will be led by Lisa Williams, directo...
# 2278  The tour will be led by Lisa Williams, directo...
# 2279  Pull on your wellies, wrap up warm and come pi...
# 2280  An Alice in Wonderland-themed afternoon tea, c...
#
# [62373 rows x 3 columns]

# %%
#comment this line if you want to save the dataframe to file
df_e_desc.to_pickle(dataframes_final+"/df_event_description")

# %% [markdown]
# ## 3. EVENTS_CATEGORY DATAFRAME

# %%
df_new_events['category']
# Out:
# 0          Music
# 1          Music
# 2         Comedy
# 3         Comedy
# 4         Comedy
#           ...
# 2272       Sport
# 2276    Days out
# 2278    Days out
# 2279    Days out
# 2280    Days out
# Name: category, Length: 38700, dtype: object

# %%
df_e_category=df_new_events[['event_id','category']]
df_e_category
# Out:
#       event_id  category
# 0       157884     Music
# 1       194419     Music
# 2       240818    Comedy
# 3       345866    Comedy
# 4       347164    Comedy
# ...        ...       ...
# 2272   1584208     Sport
# 2276   1586592  Days out
# 2278   1595055  Days out
# 2279   1599103  Days out
# 2280   1603922  Days out
#
# [38700 rows x 2 columns]

# %%
df_e_category.to_pickle(dataframes_final+"/df_event_category")

# %% [markdown]
# ## 4. EVENTS_PROPERTIES DATAFRAME

# %%
df_e_prop=df_new_events[['event_id','properties']]
df_e_prop=pd.concat([df_e_prop.drop(['properties'], axis=1), df_e_prop['properties'].apply(pd.Series)], axis=1)
df_e_prop
# Out:
#       event_id actor actor:sample affiliate:getmein affiliate:seatwave author  \
# 0       157884   NaN          NaN               NaN                NaN    NaN
# 1       194419   NaN          NaN               NaN                NaN    NaN
# 2       240818   NaN          NaN               NaN                NaN    NaN
# 3       345866   NaN          NaN               NaN                NaN    NaN
# 4       347164   NaN          NaN               NaN                NaN    NaN
# ...        ...   ...          ...               ...                ...    ...
# 2272   1584208   NaN          NaN               NaN                NaN    NaN
# 2276   1586592   NaN          NaN               NaN                NaN    NaN
# 2278   1595055   NaN          NaN               NaN                NaN    NaN
# 2279   1599103   NaN          NaN               NaN                NaN    NaN
# 2280   1603922   NaN          NaN               NaN                NaN    NaN
#
#      awards:fringe-sustainable-practice:2015  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 2272                                     NaN
# 2276                                     NaN
# 2278                                     NaN
# 2279                                     NaN
# 2280                                     NaN
#
#      awards:fringe-sustainable-practice:2017  booking_essential cast  ...  \
# 0                                         NaN             False  NaN  ...
# 1                                         NaN             False  NaN  ...
# 2                                         NaN             False  NaN  ...
# 3                                         NaN             False  NaN  ...
# 4                                         NaN             False  NaN  ...
# ...                                       ...               ...  ...  ...
# 2272                                      NaN             False  NaN  ...
# 2276                                      NaN             False  NaN  ...
# 2278                                      NaN             False  NaN  ...
# 2279                                      NaN             False  NaN  ...
# 2280                                      NaN             False  NaN  ...
#
#      list:website:comments-enabled list:website:comments-end-date  \
# 0                              NaN            2013-01-31 00:00:00
# 1                              NaN            2020-01-28 05:01:07
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# ...                            ...                            ...
# 2272                           NaN                            NaN
# 2276                           NaN                            NaN
# 2278                           NaN                            NaN
# 2279                           NaN                            NaN
# 2280                           NaN                            NaN
#
#      list:website:company list:website:hitlisted list:website:list-of-sites  \
# 0                     NaN                    NaN                        NaN
# 1                     NaN                    NaN                        NaN
# 2                     NaN                    NaN                        NaN
# 3                     NaN                    NaN                        NaN
# 4                     NaN                    NaN                        NaN
# ...                   ...                    ...                        ...
# 2272                  NaN                    NaN                        NaN
# 2276                  NaN                    NaN                        NaN
# 2278                  NaN                    NaN                        NaN
# 2279                  NaN                    NaN                        NaN
# 2280                  NaN                    NaN                        NaN
#
#      organisation pa:rating place:capacity:max simpleview:original:categories  \
# 0             NaN       NaN                NaN                            NaN
# 1             NaN       NaN                NaN                            NaN
# 2             NaN       NaN                NaN                            NaN
# 3             NaN       NaN                NaN                            NaN
# 4             NaN       NaN                NaN                            NaN
# ...           ...       ...                ...                            ...
# 2272          NaN       NaN                NaN                            NaN
# 2276          NaN       NaN                NaN                            NaN
# 2278          NaN       NaN                NaN                            NaN
# 2279          NaN       NaN                NaN                            NaN
# 2280          NaN       NaN                NaN                            NaN
#
#      writer
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 2272    NaN
# 2276    NaN
# 2278    NaN
# 2279    NaN
# 2280    NaN
#
# [38700 rows x 49 columns]

# %%
df_e_prop.to_pickle(dataframes_final+"/df_event_properties")

# %% [markdown]
# ## 5. EVENTS_TAGS Dataframe

# %%
df_e_tags=df_new_events[['event_id','tags']].explode('tags')
df_e_tags=df_e_tags[df_e_tags['tags'].notna()]

# %%
df_e_tags.to_pickle(dataframes_final+"/df_event_tags")

# %% [markdown]
# ## 6 EVENTS_PHONE_NUMBER DATAFRAME

# %%
df_events_pn=df_new_events[['event_id', 'phone_numbers']]
df_events_pn=pd.concat([df_events_pn.drop(['phone_numbers'], axis=1), df_events_pn['phone_numbers'].apply(pd.Series)], axis=1)
df_events_pn=df_events_pn.drop(0, axis=1)
df_events_pn
# Out:
#       event_id box_office           info
# 0       157884        NaN            NaN
# 1       194419        NaN            NaN
# 2       240818        NaN            NaN
# 3       345866        NaN            NaN
# 4       347164        NaN            NaN
# ...        ...        ...            ...
# 2272   1584208        NaN            NaN
# 2276   1586592        NaN  0131 555 5558
# 2278   1595055        NaN            NaN
# 2279   1599103        NaN  07793 600 289
# 2280   1603922        NaN  0131 333 0131
#
# [38700 rows x 3 columns]

# %%
df_events_pn.to_pickle(dataframes_final+"/df_event_phonenumber")

# %% [markdown]
# ## 7. Schedules Dataframe

# %%
df_schedules=df_new_events[['event_id', 'schedules']].explode('schedules')
df_schedules_total=pd.concat([df_schedules.drop(['schedules'], axis=1), df_schedules['schedules'].apply(pd.Series)], axis=1)
df_schedules_total
# Out:
#       event_id                   start_ts                     end_ts  \
# 0       157884  2018-04-26T20:00:00+01:00  2018-04-26T20:00:00+01:00
# 1       194419  2018-03-10T19:30:00+00:00  2018-03-10T19:30:00+00:00
# 1       194419  2018-03-08T20:00:00+00:00  2018-03-08T20:00:00+00:00
# 1       194419  2018-05-07T20:00:00+01:00  2018-05-07T20:00:00+01:00
# 2       240818  2018-01-24T20:30:00+00:00  2018-01-28T20:30:00+00:00
# ...        ...                        ...                        ...
# 2272   1584208  2020-10-10T16:00:00+01:00  2020-10-10T16:00:00+01:00
# 2276   1586592  2020-08-12T08:00:00+01:00  2020-10-30T08:00:00+00:00
# 2278   1595055  2020-09-12T10:30:00+01:00  2020-10-24T10:30:00+01:00
# 2279   1599103  2020-10-16T09:00:00+01:00  2020-10-19T09:00:00+01:00
# 2280   1603922  2020-10-25T14:00:00+00:00  2020-10-25T14:00:00+00:00
#
#       place_id                                       performances  \
# 0          383  [{'ts': '2018-04-26T20:00:00+01:00', 'duration...
# 1        11092  [{'ts': '2018-03-10T19:30:00+00:00', 'duration...
# 1        11200  [{'ts': '2018-03-08T20:00:00+00:00', 'links': ...
# 1          386  [{'ts': '2018-05-07T20:00:00+01:00', 'links': ...
# 2            1  [{'ts': '2018-01-24T20:30:00+00:00', 'links': ...
# ...        ...                                                ...
# 2272    127508  [{'ts': '2020-10-10T16:00:00+01:00', 'duration...
# 2276    127571  [{'ts': '2020-08-12T08:00:00+01:00', 'duration...
# 2278    127985  [{'ts': '2020-09-12T10:30:00+01:00', 'duration...
# 2279    128231  [{'ts': '2020-10-16T09:00:00+01:00', 'duration...
# 2280    128392  [{'ts': '2020-10-25T14:00:00+00:00', 'duration...
#
#      performance_space phone_numbers
# 0                  NaN           NaN
# 1                  NaN           NaN
# 1                  NaN           NaN
# 1                  NaN           NaN
# 2                  NaN           NaN
# ...                ...           ...
# 2272               NaN           NaN
# 2276               NaN           NaN
# 2278               NaN           NaN
# 2279               NaN           NaN
# 2280               NaN           NaN
#
# [48790 rows x 7 columns]

# %%
df_schedules=df_schedules_total[['event_id', 'start_ts', 'end_ts', 'place_id', 'performance_space']]
df_schedules
# Out:
#       event_id                   start_ts                     end_ts  \
# 0       157884  2018-04-26T20:00:00+01:00  2018-04-26T20:00:00+01:00
# 1       194419  2018-03-10T19:30:00+00:00  2018-03-10T19:30:00+00:00
# 1       194419  2018-03-08T20:00:00+00:00  2018-03-08T20:00:00+00:00
# 1       194419  2018-05-07T20:00:00+01:00  2018-05-07T20:00:00+01:00
# 2       240818  2018-01-24T20:30:00+00:00  2018-01-28T20:30:00+00:00
# ...        ...                        ...                        ...
# 2272   1584208  2020-10-10T16:00:00+01:00  2020-10-10T16:00:00+01:00
# 2276   1586592  2020-08-12T08:00:00+01:00  2020-10-30T08:00:00+00:00
# 2278   1595055  2020-09-12T10:30:00+01:00  2020-10-24T10:30:00+01:00
# 2279   1599103  2020-10-16T09:00:00+01:00  2020-10-19T09:00:00+01:00
# 2280   1603922  2020-10-25T14:00:00+00:00  2020-10-25T14:00:00+00:00
#
#       place_id performance_space
# 0          383               NaN
# 1        11092               NaN
# 1        11200               NaN
# 1          386               NaN
# 2            1               NaN
# ...        ...               ...
# 2272    127508               NaN
# 2276    127571               NaN
# 2278    127985               NaN
# 2279    128231               NaN
# 2280    128392               NaN
#
# [48790 rows x 5 columns]

# %%
df_schedules.to_pickle(dataframes_final+"/df_schedules")

# %% [markdown]
# ## 8. Schedules _TAGS DATAFRAME ???
#
# NOTE: SCHEDULES DO NOT HAVE TAGS - so that part of the ontology is wrong - you should correct the ontology.

# %% [markdown]
# ## 8. Schedules_PhoneNumber Dataframe

# %%
df_schedules_pn=df_schedules_total[['event_id', 'start_ts', 'place_id','end_ts', 'phone_numbers']]
df_schedules_pn=df_schedules_pn[df_schedules_pn['phone_numbers'].notna()]
df_schedules_pn
# Out:
#       event_id                   start_ts  place_id  \
# 65       58304  2018-04-29T19:30:00+01:00       610
# 100     834033  2020-01-24T21:00:00+00:00       377
# 145     943017  2018-04-08T11:30:00+01:00       379
# 182     345799  2019-08-17T20:00:00+01:00       381
# 339     557533  2018-09-29T19:30:00+01:00       383
# ...        ...                        ...       ...
# 2898   1680444  2021-08-15T20:30:00+01:00    129818
# 2899   1680445  2021-08-14T20:30:00+01:00    129818
# 2900   1680449  2021-08-26T20:30:00+01:00    129818
# 2901   1680450  2021-08-17T20:30:00+01:00    129818
# 2902   1680455  2021-08-09T20:30:00+01:00    129818
#
#                          end_ts              phone_numbers
# 65    2018-04-29T19:30:00+01:00   {'info': '01506 777666'}
# 100   2020-01-24T21:00:00+00:00  {'info': '0844 573 8455'}
# 145   2018-04-08T11:30:00+01:00  {'info': '0844 557 2686'}
# 182   2019-08-17T20:00:00+01:00  {'info': '0131 473 2000'}
# 339   2018-09-29T19:30:00+01:00    {'info': '01316682019'}
# ...                         ...                        ...
# 2898  2021-08-15T20:30:00+01:00  {'info': '0131 473 2000'}
# 2899  2021-08-14T20:30:00+01:00  {'info': '0131 473 2000'}
# 2900  2021-08-26T20:30:00+01:00  {'info': '0131 473 2000'}
# 2901  2021-08-17T20:30:00+01:00  {'info': '0131 473 2000'}
# 2902  2021-08-09T20:30:00+01:00  {'info': '0131 473 2000'}
#
# [3054 rows x 5 columns]

# %%
df_schedules_pn=pd.concat([df_schedules_pn.drop(['phone_numbers'], axis=1), df_schedules_pn['phone_numbers'].apply(pd.Series)], axis=1)

df_schedules_pn
# Out:
#       event_id                   start_ts  place_id  \
# 65       58304  2018-04-29T19:30:00+01:00       610
# 100     834033  2020-01-24T21:00:00+00:00       377
# 145     943017  2018-04-08T11:30:00+01:00       379
# 182     345799  2019-08-17T20:00:00+01:00       381
# 339     557533  2018-09-29T19:30:00+01:00       383
# ...        ...                        ...       ...
# 2898   1680444  2021-08-15T20:30:00+01:00    129818
# 2899   1680445  2021-08-14T20:30:00+01:00    129818
# 2900   1680449  2021-08-26T20:30:00+01:00    129818
# 2901   1680450  2021-08-17T20:30:00+01:00    129818
# 2902   1680455  2021-08-09T20:30:00+01:00    129818
#
#                          end_ts           info
# 65    2018-04-29T19:30:00+01:00   01506 777666
# 100   2020-01-24T21:00:00+00:00  0844 573 8455
# 145   2018-04-08T11:30:00+01:00  0844 557 2686
# 182   2019-08-17T20:00:00+01:00  0131 473 2000
# 339   2018-09-29T19:30:00+01:00    01316682019
# ...                         ...            ...
# 2898  2021-08-15T20:30:00+01:00  0131 473 2000
# 2899  2021-08-14T20:30:00+01:00  0131 473 2000
# 2900  2021-08-26T20:30:00+01:00  0131 473 2000
# 2901  2021-08-17T20:30:00+01:00  0131 473 2000
# 2902  2021-08-09T20:30:00+01:00  0131 473 2000
#
# [3054 rows x 5 columns]

# %%
df_schedules_pn.to_pickle(dataframes_final+"/df_schedules_phone_numbers")

# %% [markdown]
# ## 9. Performances Dataframe

# %%
df_total_performances=df_schedules_total[['event_id','place_id', 'start_ts', 'end_ts', 'performances']].explode('performances')
df_total_performances=pd.concat([df_total_performances.drop(['performances'], axis=1), df_total_performances['performances'].apply(pd.Series)], axis=1)
#### NEW FOR DROPPING REPEATED PERFORMANCES
df_total_performances=df_total_performances.drop_duplicates(subset=['ts', 'place_id','start_ts', 'end_ts', 'event_id'], keep="first")
df_total_performances
# Out:
#       event_id  place_id                   start_ts  \
# 0       157884       383  2018-04-26T20:00:00+01:00
# 1       194419     11092  2018-03-10T19:30:00+00:00
# 1       194419     11200  2018-03-08T20:00:00+00:00
# 1       194419       386  2018-05-07T20:00:00+01:00
# 2       240818         1  2018-01-24T20:30:00+00:00
# ...        ...       ...                        ...
# 2279   1599103    128231  2020-10-16T09:00:00+01:00
# 2279   1599103    128231  2020-10-16T09:00:00+01:00
# 2279   1599103    128231  2020-10-16T09:00:00+01:00
# 2279   1599103    128231  2020-10-16T09:00:00+01:00
# 2280   1603922    128392  2020-10-25T14:00:00+00:00
#
#                          end_ts                         ts  duration  \
# 0     2018-04-26T20:00:00+01:00  2018-04-26T20:00:00+01:00     150.0
# 1     2018-03-10T19:30:00+00:00  2018-03-10T19:30:00+00:00     120.0
# 1     2018-03-08T20:00:00+00:00  2018-03-08T20:00:00+00:00       NaN
# 1     2018-05-07T20:00:00+01:00  2018-05-07T20:00:00+01:00       NaN
# 2     2018-01-28T20:30:00+00:00  2018-01-24T20:30:00+00:00       NaN
# ...                         ...                        ...       ...
# 2279  2020-10-19T09:00:00+01:00  2020-10-16T09:00:00+01:00     480.0
# 2279  2020-10-19T09:00:00+01:00  2020-10-17T09:00:00+01:00     480.0
# 2279  2020-10-19T09:00:00+01:00  2020-10-18T09:00:00+01:00     480.0
# 2279  2020-10-19T09:00:00+01:00  2020-10-19T09:00:00+01:00     480.0
# 2280  2020-10-25T14:00:00+00:00  2020-10-25T14:00:00+00:00     240.0
#
#                                                   links  \
# 0     [{'type': 'booking', 'url': 'http://www.theque...
# 1                                                   NaN
# 1     [{'type': 'booking', 'url': 'https://www.ticke...
# 1     [{'type': 'booking', 'url': 'https://www.trave...
# 2     [{'type': 'booking', 'url': 'http://www.thesta...
# ...                                                 ...
# 2279  [{'type': 'booking', 'url': 'https://www.kildu...
# 2279  [{'type': 'booking', 'url': 'https://www.kildu...
# 2279  [{'type': 'booking', 'url': 'https://www.kildu...
# 2279  [{'type': 'booking', 'url': 'https://www.kildu...
# 2280                                                NaN
#
#                                                 tickets  \
# 0     [{'type': 'Standard', 'currency': 'GBP', 'min_...
# 1     [{'type': 'Standard', 'currency': 'GBP', 'min_...
# 1     [{'type': 'Standard', 'currency': 'GBP', 'desc...
# 1     [{'type': 'Standard', 'currency': 'GBP', 'min_...
# 2     [{'type': 'Standard', 'currency': 'GBP', 'min_...
# ...                                                 ...
# 2279  [{'type': 'Standard', 'currency': 'GBP', 'min_...
# 2279  [{'type': 'Standard', 'currency': 'GBP', 'min_...
# 2279  [{'type': 'Standard', 'currency': 'GBP', 'min_...
# 2279  [{'type': 'Standard', 'currency': 'GBP', 'min_...
# 2280          [{'type': 'Standard', 'currency': 'GBP'}]
#
#                           properties  \
# 0                                NaN
# 1                                NaN
# 1     {'performance.sold-out': True}
# 1                                NaN
# 2                                NaN
# ...                              ...
# 2279                             NaN
# 2279                             NaN
# 2279                             NaN
# 2279                             NaN
# 2280                             NaN
#
#                                            descriptions time_unknown
# 0                                                   NaN          NaN
# 1                                                   NaN          NaN
# 1                                                   NaN          NaN
# 1                                                   NaN          NaN
# 2     [{'type': 'list.description.default', 'descrip...          NaN
# ...                                                 ...          ...
# 2279                                                NaN          NaN
# 2279                                                NaN          NaN
# 2279                                                NaN          NaN
# 2279                                                NaN          NaN
# 2280                                                NaN          NaN
#
# [354808 rows x 11 columns]

# %%
df_performaces=df_total_performances[['event_id','place_id', 'start_ts', 'end_ts', 'ts', 'duration', 'time_unknown' ]]

# %%
#comment this line if you want to save the dataframe to file
df_performaces.to_pickle(dataframes_final+"/df_performances")

# %% [markdown]
# ## 10. PERFORMANCES_PROPERTIES DATAFRAME
#
#
# **IMPORTANT** WE HAVE REALISED THAT WE DONT LONGER NEED THESE THREE NODES: PROPERTYEVENTS, THEATHRE AND FILM
# ALL the properties of these 3 nodes are now PERFORMANCE_PROPERTY.
#
# The ontology should be updated to reflect this

# %% [markdown]
# Note: The follow cell takes 2 or 3 mintues to run

# %%
df_p_prop_total=df_total_performances[['event_id', 'place_id','start_ts', 'end_ts', 'ts', 'properties']]
df_p_prop_total= df_p_prop_total[df_p_prop_total['properties'].notna()]
df_p_prop=pd.concat([df_p_prop_total.drop(['properties'], axis=1), df_p_prop_total['properties'].apply(pd.Series)], axis=1)

# %%
df_p_prop.drop_duplicates(keep='first')
# Out:
#       event_id  place_id                   start_ts  \
# 1       194419     11200  2018-03-08T20:00:00+00:00
# 3       345866         1  2018-11-05T20:30:00+00:00
# 3       345866         1  2018-11-05T20:30:00+00:00
# 3       345866         1  2018-11-05T20:30:00+00:00
# 3       345866         1  2018-11-05T20:30:00+00:00
# ...        ...       ...                        ...
# 2278   1595055    127985  2020-09-12T10:30:00+01:00
# 2278   1595055    127985  2020-09-12T10:30:00+01:00
# 2278   1595055    127985  2020-09-12T10:30:00+01:00
# 2278   1595055    127985  2020-09-12T10:30:00+01:00
# 2278   1595055    127985  2020-09-12T10:30:00+01:00
#
#                          end_ts                         ts  \
# 1     2018-03-08T20:00:00+00:00  2018-03-08T20:00:00+00:00
# 3     2019-04-29T20:30:00+01:00  2019-02-04T20:30:00+00:00
# 3     2019-04-29T20:30:00+01:00  2019-02-11T20:30:00+00:00
# 3     2019-04-29T20:30:00+01:00  2019-02-18T20:30:00+00:00
# 3     2019-04-29T20:30:00+01:00  2019-02-25T20:30:00+00:00
# ...                         ...                        ...
# 2278  2020-10-24T10:30:00+01:00  2020-10-09T14:30:00+01:00
# 2278  2020-10-24T10:30:00+01:00  2020-10-11T10:30:00+01:00
# 2278  2020-10-24T10:30:00+01:00  2020-10-16T14:30:00+01:00
# 2278  2020-10-24T10:30:00+01:00  2020-10-23T14:00:00+01:00
# 2278  2020-10-24T10:30:00+01:00  2020-10-24T10:30:00+01:00
#
#      performance.sold-out event.festival performance.cancelled event.support  \
# 1                    True            NaN                   NaN           NaN
# 3                     NaN   Glen's Guide                   NaN           NaN
# 3                     NaN   Glen's Guide                   NaN           NaN
# 3                     NaN   Glen's Guide                   NaN           NaN
# 3                     NaN   Glen's Guide                   NaN           NaN
# ...                   ...            ...                   ...           ...
# 2278                  NaN            NaN                   NaN           NaN
# 2278                  NaN            NaN                   NaN           NaN
# 2278                  NaN            NaN                   NaN           NaN
# 2278                  NaN            NaN                   NaN           NaN
# 2278                  NaN            NaN                   NaN           NaN
#
#      list.hitlisted  ... event.film.premium-screening event.film.over-18s  \
# 1               NaN  ...                          NaN                 NaN
# 3               NaN  ...                          NaN                 NaN
# 3               NaN  ...                          NaN                 NaN
# 3               NaN  ...                          NaN                 NaN
# 3               NaN  ...                          NaN                 NaN
# ...             ...  ...                          ...                 ...
# 2278           True  ...                          NaN                 NaN
# 2278           True  ...                          NaN                 NaN
# 2278           True  ...                          NaN                 NaN
# 2278           True  ...                          NaN                 NaN
# 2278           True  ...                          NaN                 NaN
#
#      event.film.parent-and-baby event.film.senior event.film.subtitled  \
# 1                           NaN               NaN                  NaN
# 3                           NaN               NaN                  NaN
# 3                           NaN               NaN                  NaN
# 3                           NaN               NaN                  NaN
# 3                           NaN               NaN                  NaN
# ...                         ...               ...                  ...
# 2278                        NaN               NaN                  NaN
# 2278                        NaN               NaN                  NaN
# 2278                        NaN               NaN                  NaN
# 2278                        NaN               NaN                  NaN
# 2278                        NaN               NaN                  NaN
#
#      event.film.3d event.film.imax event.theatre.bsl-interpreted  \
# 1              NaN             NaN                           NaN
# 3              NaN             NaN                           NaN
# 3              NaN             NaN                           NaN
# 3              NaN             NaN                           NaN
# 3              NaN             NaN                           NaN
# ...            ...             ...                           ...
# 2278           NaN             NaN                           NaN
# 2278           NaN             NaN                           NaN
# 2278           NaN             NaN                           NaN
# 2278           NaN             NaN                           NaN
# 2278           NaN             NaN                           NaN
#
#      event.film.autism-friendly event.theatre.captioned
# 1                           NaN                     NaN
# 3                           NaN                     NaN
# 3                           NaN                     NaN
# 3                           NaN                     NaN
# 3                           NaN                     NaN
# ...                         ...                     ...
# 2278                        NaN                     NaN
# 2278                        NaN                     NaN
# 2278                        NaN                     NaN
# 2278                        NaN                     NaN
# 2278                        NaN                     NaN
#
# [181501 rows x 22 columns]

# %%
df_p_prop.to_pickle(dataframes_final+"/df_performances_properties")

# %% [markdown]
# ## 11. PERFORMANCES DESCRIPTION

# %%
df_p_desc=df_total_performances[['event_id', 'start_ts','place_id', 'end_ts', 'ts','descriptions']].explode('descriptions')
df_p_desc=df_p_desc[df_p_desc['descriptions'].notna()]
df_p_desc=pd.concat([df_p_desc.drop(['descriptions'], axis=1), df_p_desc['descriptions'].apply(pd.Series)], axis=1)
df_p_desc
# Out:
#       event_id                   start_ts  place_id  \
# 2       240818  2018-01-24T20:30:00+00:00         1
# 2       240818  2018-01-24T20:30:00+00:00         1
# 3       345866  2017-11-06T20:30:00+00:00         1
# 3       345866  2017-11-06T20:30:00+00:00         1
# 3       345866  2017-11-06T20:30:00+00:00         1
# ...        ...                        ...       ...
# 2253   1582837  2020-08-27T18:00:00+01:00    127344
# 2253   1582837  2020-08-27T18:00:00+01:00    127344
# 2253   1582837  2020-08-27T18:00:00+01:00    127344
# 2253   1582837  2020-08-27T18:00:00+01:00    127344
# 2253   1582837  2020-08-27T18:00:00+01:00    127344
#
#                          end_ts                         ts  \
# 2     2018-01-28T20:30:00+00:00  2018-01-24T20:30:00+00:00
# 2     2018-01-28T20:30:00+00:00  2018-01-28T20:30:00+00:00
# 3     2018-04-30T20:30:00+01:00  2017-11-13T20:30:00+00:00
# 3     2018-04-30T20:30:00+01:00  2017-11-20T20:30:00+00:00
# 3     2018-04-30T20:30:00+01:00  2017-11-27T20:30:00+00:00
# ...                         ...                        ...
# 2253  2020-10-31T00:00:00+00:00  2020-08-29T22:00:00+01:00
# 2253  2020-10-31T00:00:00+00:00  2020-08-30T10:30:00+01:00
# 2253  2020-10-31T00:00:00+00:00  2020-08-30T14:00:00+01:00
# 2253  2020-10-31T00:00:00+00:00  2020-08-30T17:45:00+01:00
# 2253  2020-10-31T00:00:00+00:00  2020-08-30T22:00:00+01:00
#
#                           type  \
# 2     list.description.default
# 2     list.description.default
# 3     list.description.default
# 3     list.description.default
# 3     list.description.default
# ...                        ...
# 2253  list.description.default
# 2253  list.description.default
# 2253  list.description.default
# 2253  list.description.default
# 2253  list.description.default
#
#                                             description
# 2     With Vladimir McTavish, Jim Smith, Wisarut Jan...
# 2     With Stephen Carlin, Gus Lymburn, Donald Alexa...
# 3       With host Gareth Mutch and headliner Jim Smith.
# 3                       With headliner Stuart Mitchell.
# 3                           With headliner Peter Brush.
# ...                                                 ...
# 2253                                       Alien (1979)
# 2253                                          Up (2009)
# 2253                          The Princess Bride (1987)
# 2253                                  La La Land (2017)
# 2253                               Dirty Dancing (1987)
#
# [49419 rows x 7 columns]

# %%
df_p_desc.drop_duplicates(keep='first')
# Out:
#       event_id                   start_ts  place_id  \
# 2       240818  2018-01-24T20:30:00+00:00         1
# 2       240818  2018-01-24T20:30:00+00:00         1
# 3       345866  2017-11-06T20:30:00+00:00         1
# 3       345866  2017-11-06T20:30:00+00:00         1
# 3       345866  2017-11-06T20:30:00+00:00         1
# ...        ...                        ...       ...
# 2253   1582837  2020-08-27T18:00:00+01:00    127344
# 2253   1582837  2020-08-27T18:00:00+01:00    127344
# 2253   1582837  2020-08-27T18:00:00+01:00    127344
# 2253   1582837  2020-08-27T18:00:00+01:00    127344
# 2253   1582837  2020-08-27T18:00:00+01:00    127344
#
#                          end_ts                         ts  \
# 2     2018-01-28T20:30:00+00:00  2018-01-24T20:30:00+00:00
# 2     2018-01-28T20:30:00+00:00  2018-01-28T20:30:00+00:00
# 3     2018-04-30T20:30:00+01:00  2017-11-13T20:30:00+00:00
# 3     2018-04-30T20:30:00+01:00  2017-11-20T20:30:00+00:00
# 3     2018-04-30T20:30:00+01:00  2017-11-27T20:30:00+00:00
# ...                         ...                        ...
# 2253  2020-10-31T00:00:00+00:00  2020-08-29T22:00:00+01:00
# 2253  2020-10-31T00:00:00+00:00  2020-08-30T10:30:00+01:00
# 2253  2020-10-31T00:00:00+00:00  2020-08-30T14:00:00+01:00
# 2253  2020-10-31T00:00:00+00:00  2020-08-30T17:45:00+01:00
# 2253  2020-10-31T00:00:00+00:00  2020-08-30T22:00:00+01:00
#
#                           type  \
# 2     list.description.default
# 2     list.description.default
# 3     list.description.default
# 3     list.description.default
# 3     list.description.default
# ...                        ...
# 2253  list.description.default
# 2253  list.description.default
# 2253  list.description.default
# 2253  list.description.default
# 2253  list.description.default
#
#                                             description
# 2     With Vladimir McTavish, Jim Smith, Wisarut Jan...
# 2     With Stephen Carlin, Gus Lymburn, Donald Alexa...
# 3       With host Gareth Mutch and headliner Jim Smith.
# 3                       With headliner Stuart Mitchell.
# 3                           With headliner Peter Brush.
# ...                                                 ...
# 2253                                       Alien (1979)
# 2253                                          Up (2009)
# 2253                          The Princess Bride (1987)
# 2253                                  La La Land (2017)
# 2253                               Dirty Dancing (1987)
#
# [49419 rows x 7 columns]

# %%
df_p_desc.to_pickle(dataframes_final+"/df_performances_descriptions")

# %% [markdown]
# ## 12. PERFORMANCE LINKS
#
# These lines takes 5 minutes to run

# %%
df_p_links=df_total_performances[['event_id', 'start_ts', 'place_id','end_ts', 'ts','links']].explode('links')
df_p_links=df_p_links[df_p_links['links'].notna()]
df_p_links=pd.concat([df_p_links.drop(['links'], axis=1), df_p_links['links'].apply(pd.Series)], axis=1)
df_p_links
# Out:
#       event_id                   start_ts  place_id  \
# 0       157884  2018-04-26T20:00:00+01:00       383
# 1       194419  2018-03-08T20:00:00+00:00     11200
# 1       194419  2018-05-07T20:00:00+01:00       386
# 2       240818  2018-01-24T20:30:00+00:00         1
# 2       240818  2018-01-24T20:30:00+00:00         1
# ...        ...                        ...       ...
# 2278   1595055  2020-09-12T10:30:00+01:00    127985
# 2279   1599103  2020-10-16T09:00:00+01:00    128231
# 2279   1599103  2020-10-16T09:00:00+01:00    128231
# 2279   1599103  2020-10-16T09:00:00+01:00    128231
# 2279   1599103  2020-10-16T09:00:00+01:00    128231
#
#                          end_ts                         ts     type  \
# 0     2018-04-26T20:00:00+01:00  2018-04-26T20:00:00+01:00  booking
# 1     2018-03-08T20:00:00+00:00  2018-03-08T20:00:00+00:00  booking
# 1     2018-05-07T20:00:00+01:00  2018-05-07T20:00:00+01:00  booking
# 2     2018-01-28T20:30:00+00:00  2018-01-24T20:30:00+00:00  booking
# 2     2018-01-28T20:30:00+00:00  2018-01-28T20:30:00+00:00  booking
# ...                         ...                        ...      ...
# 2278  2020-10-24T10:30:00+01:00  2020-10-24T10:30:00+01:00  booking
# 2279  2020-10-19T09:00:00+01:00  2020-10-16T09:00:00+01:00  booking
# 2279  2020-10-19T09:00:00+01:00  2020-10-17T09:00:00+01:00  booking
# 2279  2020-10-19T09:00:00+01:00  2020-10-18T09:00:00+01:00  booking
# 2279  2020-10-19T09:00:00+01:00  2020-10-19T09:00:00+01:00  booking
#
#                                                     url
# 0     http://www.thequeenshall.net/whats-on/shows/va...
# 1     https://www.ticketsource.co.uk/booking/date/44...
# 1     https://www.traverse.co.uk/whats-on/event-deta...
# 2     http://www.thestand.co.uk/show/29395/burns_nig...
# 2     http://www.thestand.co.uk/show/29397/burns_nig...
# ...                                                 ...
# 2278  https://www.eventbrite.com/e/black-history-wal...
# 2279                   https://www.kilduff.co.uk/patch/
# 2279                   https://www.kilduff.co.uk/patch/
# 2279                   https://www.kilduff.co.uk/patch/
# 2279                   https://www.kilduff.co.uk/patch/
#
# [267248 rows x 7 columns]

# %%
df_p_links.to_pickle(dataframes_final+"/df_performances_links")

# %% [markdown]
# ## 13. TICKETS
#
# This cell takes 5 minutes to run

# %%
df_tickets=df_total_performances[['event_id','place_id','start_ts', 'end_ts', 'ts','tickets']].explode('tickets')
df_tickets=df_tickets[df_tickets['tickets'].notna()]
df_tickets
df_tickets=pd.concat([df_tickets.drop(['tickets'], axis=1), df_tickets['tickets'].apply(pd.Series)], axis=1)

# %%
df_tickets
# Out:
#       event_id  place_id                   start_ts  \
# 0       157884       383  2018-04-26T20:00:00+01:00
# 1       194419     11092  2018-03-10T19:30:00+00:00
# 1       194419     11092  2018-03-10T19:30:00+00:00
# 1       194419     11092  2018-03-10T19:30:00+00:00
# 1       194419     11200  2018-03-08T20:00:00+00:00
# ...        ...       ...                        ...
# 2279   1599103    128231  2020-10-16T09:00:00+01:00
# 2279   1599103    128231  2020-10-16T09:00:00+01:00
# 2279   1599103    128231  2020-10-16T09:00:00+01:00
# 2279   1599103    128231  2020-10-16T09:00:00+01:00
# 2280   1603922    128392  2020-10-25T14:00:00+00:00
#
#                          end_ts                         ts        type  \
# 0     2018-04-26T20:00:00+01:00  2018-04-26T20:00:00+01:00    Standard
# 1     2018-03-10T19:30:00+00:00  2018-03-10T19:30:00+00:00    Standard
# 1     2018-03-10T19:30:00+00:00  2018-03-10T19:30:00+00:00  Concession
# 1     2018-03-10T19:30:00+00:00  2018-03-10T19:30:00+00:00    Children
# 1     2018-03-08T20:00:00+00:00  2018-03-08T20:00:00+00:00    Standard
# ...                         ...                        ...         ...
# 2279  2020-10-19T09:00:00+01:00  2020-10-16T09:00:00+01:00    Standard
# 2279  2020-10-19T09:00:00+01:00  2020-10-17T09:00:00+01:00    Standard
# 2279  2020-10-19T09:00:00+01:00  2020-10-18T09:00:00+01:00    Standard
# 2279  2020-10-19T09:00:00+01:00  2020-10-19T09:00:00+01:00    Standard
# 2280  2020-10-25T14:00:00+00:00  2020-10-25T14:00:00+00:00    Standard
#
#      currency  min_price description  max_price
# 0         GBP       14.0         NaN        NaN
# 1         GBP       15.0         NaN        NaN
# 1         GBP       13.0         NaN        NaN
# 1         GBP        6.0         NaN        NaN
# 1         GBP        NaN         tbc        NaN
# ...       ...        ...         ...        ...
# 2279      GBP        1.0         NaN        NaN
# 2279      GBP        1.0         NaN        NaN
# 2279      GBP        1.0         NaN        NaN
# 2279      GBP        1.0         NaN        NaN
# 2280      GBP        NaN         NaN        NaN
#
# [483714 rows x 10 columns]

# %%
df_ticketDescription=df_tickets[['event_id','place_id','start_ts', 'type','end_ts', 'ts','description']]

df_ticketsDescription= df_ticketDescription[df_ticketDescription['description'].notna()]
df_ticketsDescription
# Out:
#       event_id  place_id                   start_ts      type  \
# 1       194419     11200  2018-03-08T20:00:00+00:00  Standard
# 4       347164         1  2019-05-04T20:30:00+01:00  Standard
# 4       347164         1  2019-05-04T20:30:00+01:00  Standard
# 4       347164         1  2019-05-04T20:30:00+01:00  Standard
# 4       347164         1  2019-05-04T20:30:00+01:00  Standard
# ...        ...       ...                        ...       ...
# 2112   1542024    103236  2020-05-22T19:30:00+01:00  Standard
# 2127   1443727    104128  2020-07-11T20:00:00+01:00  Standard
# 2142   1237645    106273  2020-07-23T11:00:00+01:00  Standard
# 2157   1547779    114954  2020-06-14T19:30:00+01:00  Standard
# 2192   1594444    119098  2020-10-20T10:00:00+01:00  Standard
#
#                          end_ts                         ts  \
# 1     2018-03-08T20:00:00+00:00  2018-03-08T20:00:00+00:00
# 4     2019-10-26T20:30:00+01:00  2019-08-31T20:30:00+01:00
# 4     2019-10-26T20:30:00+01:00  2019-09-07T20:30:00+01:00
# 4     2019-10-26T20:30:00+01:00  2019-09-14T20:30:00+01:00
# 4     2019-10-26T20:30:00+01:00  2019-09-21T20:30:00+01:00
# ...                         ...                        ...
# 2112  2020-05-22T19:30:00+01:00  2020-05-22T19:30:00+01:00
# 2127  2020-07-11T20:00:00+01:00  2020-07-11T20:00:00+01:00
# 2142  2020-07-23T11:00:00+01:00  2020-07-23T11:00:00+01:00
# 2157  2020-06-14T19:30:00+01:00  2020-06-14T19:30:00+01:00
# 2192  2020-10-20T10:00:00+01:00  2020-10-20T10:00:00+01:00
#
#                                             description
# 1                                                   tbc
# 4                                                  £tbc
# 4                                                  £tbc
# 4                                                  £tbc
# 4                                                  £tbc
# ...                                                 ...
# 2112  Adults £15\n16 years and under £10\nIncludes b...
# 2127                                               £tbc
# 2142                                                tbc
# 2157                                               £tbc
# 2192                                                tbc
#
# [25892 rows x 7 columns]

# %%
df_ticketsDescription=df_ticketsDescription.drop_duplicates(keep='first')
df_ticketsDescription
# Out:
#       event_id  place_id                   start_ts      type  \
# 1       194419     11200  2018-03-08T20:00:00+00:00  Standard
# 4       347164         1  2019-05-04T20:30:00+01:00  Standard
# 4       347164         1  2019-05-04T20:30:00+01:00  Standard
# 4       347164         1  2019-05-04T20:30:00+01:00  Standard
# 4       347164         1  2019-05-04T20:30:00+01:00  Standard
# ...        ...       ...                        ...       ...
# 2112   1542024    103236  2020-05-22T19:30:00+01:00  Standard
# 2127   1443727    104128  2020-07-11T20:00:00+01:00  Standard
# 2142   1237645    106273  2020-07-23T11:00:00+01:00  Standard
# 2157   1547779    114954  2020-06-14T19:30:00+01:00  Standard
# 2192   1594444    119098  2020-10-20T10:00:00+01:00  Standard
#
#                          end_ts                         ts  \
# 1     2018-03-08T20:00:00+00:00  2018-03-08T20:00:00+00:00
# 4     2019-10-26T20:30:00+01:00  2019-08-31T20:30:00+01:00
# 4     2019-10-26T20:30:00+01:00  2019-09-07T20:30:00+01:00
# 4     2019-10-26T20:30:00+01:00  2019-09-14T20:30:00+01:00
# 4     2019-10-26T20:30:00+01:00  2019-09-21T20:30:00+01:00
# ...                         ...                        ...
# 2112  2020-05-22T19:30:00+01:00  2020-05-22T19:30:00+01:00
# 2127  2020-07-11T20:00:00+01:00  2020-07-11T20:00:00+01:00
# 2142  2020-07-23T11:00:00+01:00  2020-07-23T11:00:00+01:00
# 2157  2020-06-14T19:30:00+01:00  2020-06-14T19:30:00+01:00
# 2192  2020-10-20T10:00:00+01:00  2020-10-20T10:00:00+01:00
#
#                                             description
# 1                                                   tbc
# 4                                                  £tbc
# 4                                                  £tbc
# 4                                                  £tbc
# 4                                                  £tbc
# ...                                                 ...
# 2112  Adults £15\n16 years and under £10\nIncludes b...
# 2127                                               £tbc
# 2142                                                tbc
# 2157                                               £tbc
# 2192                                                tbc
#
# [25888 rows x 7 columns]

# %%
df_ticketsDescription.to_pickle(dataframes_final+"/df_ticketDescription")

# %%
df_tickets=df_tickets.drop(['description'],axis=1)
df_tickets
# Out:
#       event_id  place_id                   start_ts  \
# 0       157884       383  2018-04-26T20:00:00+01:00
# 1       194419     11092  2018-03-10T19:30:00+00:00
# 1       194419     11092  2018-03-10T19:30:00+00:00
# 1       194419     11092  2018-03-10T19:30:00+00:00
# 1       194419     11200  2018-03-08T20:00:00+00:00
# ...        ...       ...                        ...
# 2279   1599103    128231  2020-10-16T09:00:00+01:00
# 2279   1599103    128231  2020-10-16T09:00:00+01:00
# 2279   1599103    128231  2020-10-16T09:00:00+01:00
# 2279   1599103    128231  2020-10-16T09:00:00+01:00
# 2280   1603922    128392  2020-10-25T14:00:00+00:00
#
#                          end_ts                         ts        type  \
# 0     2018-04-26T20:00:00+01:00  2018-04-26T20:00:00+01:00    Standard
# 1     2018-03-10T19:30:00+00:00  2018-03-10T19:30:00+00:00    Standard
# 1     2018-03-10T19:30:00+00:00  2018-03-10T19:30:00+00:00  Concession
# 1     2018-03-10T19:30:00+00:00  2018-03-10T19:30:00+00:00    Children
# 1     2018-03-08T20:00:00+00:00  2018-03-08T20:00:00+00:00    Standard
# ...                         ...                        ...         ...
# 2279  2020-10-19T09:00:00+01:00  2020-10-16T09:00:00+01:00    Standard
# 2279  2020-10-19T09:00:00+01:00  2020-10-17T09:00:00+01:00    Standard
# 2279  2020-10-19T09:00:00+01:00  2020-10-18T09:00:00+01:00    Standard
# 2279  2020-10-19T09:00:00+01:00  2020-10-19T09:00:00+01:00    Standard
# 2280  2020-10-25T14:00:00+00:00  2020-10-25T14:00:00+00:00    Standard
#
#      currency  min_price  max_price
# 0         GBP       14.0        NaN
# 1         GBP       15.0        NaN
# 1         GBP       13.0        NaN
# 1         GBP        6.0        NaN
# 1         GBP        NaN        NaN
# ...       ...        ...        ...
# 2279      GBP        1.0        NaN
# 2279      GBP        1.0        NaN
# 2279      GBP        1.0        NaN
# 2279      GBP        1.0        NaN
# 2280      GBP        NaN        NaN
#
# [483714 rows x 9 columns]

# %%
df_tickets=df_tickets.drop_duplicates(keep='first')
df_tickets
# Out:
#       event_id  place_id                   start_ts  \
# 0       157884       383  2018-04-26T20:00:00+01:00
# 1       194419     11092  2018-03-10T19:30:00+00:00
# 1       194419     11092  2018-03-10T19:30:00+00:00
# 1       194419     11092  2018-03-10T19:30:00+00:00
# 1       194419     11200  2018-03-08T20:00:00+00:00
# ...        ...       ...                        ...
# 2279   1599103    128231  2020-10-16T09:00:00+01:00
# 2279   1599103    128231  2020-10-16T09:00:00+01:00
# 2279   1599103    128231  2020-10-16T09:00:00+01:00
# 2279   1599103    128231  2020-10-16T09:00:00+01:00
# 2280   1603922    128392  2020-10-25T14:00:00+00:00
#
#                          end_ts                         ts        type  \
# 0     2018-04-26T20:00:00+01:00  2018-04-26T20:00:00+01:00    Standard
# 1     2018-03-10T19:30:00+00:00  2018-03-10T19:30:00+00:00    Standard
# 1     2018-03-10T19:30:00+00:00  2018-03-10T19:30:00+00:00  Concession
# 1     2018-03-10T19:30:00+00:00  2018-03-10T19:30:00+00:00    Children
# 1     2018-03-08T20:00:00+00:00  2018-03-08T20:00:00+00:00    Standard
# ...                         ...                        ...         ...
# 2279  2020-10-19T09:00:00+01:00  2020-10-16T09:00:00+01:00    Standard
# 2279  2020-10-19T09:00:00+01:00  2020-10-17T09:00:00+01:00    Standard
# 2279  2020-10-19T09:00:00+01:00  2020-10-18T09:00:00+01:00    Standard
# 2279  2020-10-19T09:00:00+01:00  2020-10-19T09:00:00+01:00    Standard
# 2280  2020-10-25T14:00:00+00:00  2020-10-25T14:00:00+00:00    Standard
#
#      currency  min_price  max_price
# 0         GBP       14.0        NaN
# 1         GBP       15.0        NaN
# 1         GBP       13.0        NaN
# 1         GBP        6.0        NaN
# 1         GBP        NaN        NaN
# ...       ...        ...        ...
# 2279      GBP        1.0        NaN
# 2279      GBP        1.0        NaN
# 2279      GBP        1.0        NaN
# 2279      GBP        1.0        NaN
# 2280      GBP        NaN        NaN
#
# [483700 rows x 9 columns]

# %%
# un-comment this line if you want to save the df_p_properties into a file
df_tickets.to_pickle(dataframes_final+"/df_tickets")

# %% [markdown]
# ## 14. PLACES

# %%
with open("/content/drive/MyDrive/df_places","rb") as df_places:
    df_places_total=pickle.load(df_places)

# %%
df_places_total.iloc[0]
# Out:
# address                                               5 York Place
# email                                         admin@thestand.co.uk
# postal_code                                                EH1 3EB
# properties       {'place.child-restrictions': True, 'place.faci...
# sort_name                                                    Stand
# town                                                     Edinburgh
# website                                  http://www.thestand.co.uk
# place_id                                                         1
# modified_ts                                   2021-11-24T12:18:33Z
# created_ts                                    2021-11-24T12:18:33Z
# name                                                     The Stand
# loc              {'latitude': '55.955806109395006', 'longitude'...
# country_code                                                    GB
# tags                 [Bar & pub food, Comedy, Restaurants, Venues]
# descriptions     [{'type': 'description.list.default', 'descrip...
# phone_numbers    {'info': '0131 558 7272', 'box_office': '0131 ...
# status                                                        live
# Name: 0, dtype: object

# %%
df_places=df_places_total[['place_id', 'created_ts', 'modified_ts', 'name', 'sort_name', 'address', 'town', 'postal_code', 'country_code', 'website', 'email', 'status']]
df_places
# Out:
#      place_id            created_ts           modified_ts  \
# 0           1  2021-11-24T12:18:33Z  2021-11-24T12:18:33Z
# 1         371  2019-12-04T13:27:26Z  2019-12-04T13:27:26Z
# 2         372  2021-02-23T16:57:44Z  2021-02-23T16:57:44Z
# 3         375  2015-02-18T15:59:38Z  2015-02-18T15:59:38Z
# 4         376  2020-01-27T10:18:15Z  2020-01-27T10:18:15Z
# ..        ...                   ...                   ...
# 512    127508  2020-07-22T16:37:19Z  2020-07-22T16:37:19Z
# 514    127985  2020-09-06T21:18:42Z  2020-09-06T21:18:42Z
# 515    128007  2020-09-08T17:49:40Z  2020-09-08T17:49:40Z
# 516    128231  2020-09-22T17:58:11Z  2020-09-22T17:58:11Z
# 517    128392  2020-10-13T17:34:36Z  2020-10-13T17:34:36Z
#
#                            name                   sort_name  \
# 0                     The Stand                       Stand
# 1             St Bride's Centre           St Bride's Centre
# 2    Institut Français d'Ecosse  Institut Français d'Ecosse
# 3      Meadowbank Sports Centre    Meadowbank Sports Centre
# 4         Royal Highland Centre       Royal Highland Centre
# ..                          ...                         ...
# 512           Lochgelly Raceway           Lochgelly Raceway
# 514           Melville Monument           Melville Monument
# 515        Edinburgh Technopole        Edinburgh Technopole
# 516                Kilduff Farm                Kilduff Farm
# 517                    Hub Cafe                    Hub Cafe
#
#                                                address           town  \
# 0                                         5 York Place      Edinburgh
# 1                                    10 Orwell Terrace      Edinburgh
# 2                               West Parliament Square      Edinburgh
# 3                                      139 London Road      Edinburgh
# 4                                            Ingliston      Edinburgh
# ..                                                 ...            ...
# 512                                                A92      Lochgelly
# 514                                42 St Andrew Square      Edinburgh
# 515                                      Milton Bridge      Edinburgh
# 516                                  Kilduff Farm Drem  North Berwick
# 517  Technopole\nPioneer Building\nGround Floor\nMi...      Edinburgh
#
#     postal_code country_code                                  website  \
# 0       EH1 3EB           GB                http://www.thestand.co.uk
# 1      EH11 2DY           GB            http://stbrides.wordpress.com
# 2       EH1 1RN           GB               http://www.ifecosse.org.uk
# 3       EH7 6AE           GB        http://www.edinburghleisure.co.uk
# 4      EH28 8NB           GB     http://www.royalhighlandcentre.co.uk
# ..          ...          ...                                      ...
# 512     KY5 9HG           GB  https://www.hardieracepromotions.co.uk/
# 514     EH2 2AD           GB                                      NaN
# 515    EH26 0BB           GB       https://edinburghtechnopole.co.uk/
# 516    EH39 5BD           GB                                      NaN
# 517    EH26 0PJ           GB                                      NaN
#
#                                           email status
# 0                          admin@thestand.co.uk   live
# 1                                           NaN   live
# 2    ifecosse.edimbourg-cslt@diplomatie.gouv.fr   live
# 3                                           NaN   live
# 4                                           NaN   live
# ..                                          ...    ...
# 512                                         NaN   live
# 514                                         NaN   live
# 515                                         NaN   live
# 516                                         NaN   live
# 517                                         NaN   live
#
# [2474 rows x 12 columns]

# %%
df_places.to_pickle(dataframes_final+"/df_places")

# %% [markdown]
# ## 15. PLACES PROPERTIES DATAFRAME

# %%
df_place_prop=df_places_total[['place_id','properties']]
df_place_prop=df_place_prop[df_place_prop['properties'].notna()]
df_place_prop=pd.concat([df_place_prop.drop(['properties'], axis=1), df_place_prop['properties'].apply(pd.Series)], axis=1)
df_place_prop
# Out:
#      place_id place.child-restrictions place.facilities.free-wifi  \
# 0           1                     True                       True
# 2         372                      NaN                      False
# 3         375                      NaN                        NaN
# 4         376                      NaN                        NaN
# 5         377                      NaN                        NaN
# ..        ...                      ...                        ...
# 477    124806                      NaN                       True
# 485    127866                      NaN                       True
# 501    129920                      NaN                      False
# 374     62062                      NaN                       True
# 439    101921                    False                       True
#
#     place.facilities.dogs-allowed place.facilities.parking  \
# 0                           False                     True
# 2                             NaN                    False
# 3                             NaN                      NaN
# 4                             NaN                      NaN
# 5                             NaN                      NaN
# ..                            ...                      ...
# 477                           NaN                    False
# 485                           NaN                    False
# 501                           NaN                    False
# 374                           NaN                     True
# 439                          True                    False
#
#     place.facilities.toilets place.facilities.toilets_disabled  \
# 0                       True                             False
# 2                      False                             False
# 3                        NaN                               NaN
# 4                        NaN                               NaN
# 5                        NaN                               NaN
# ..                       ...                               ...
# 477                     True                              True
# 485                     True                             False
# 501                     True                              True
# 374                     True                              True
# 439                     True                              True
#
#     place.facilities.wheelchair-access place.capacity.max  \
# 0                                False                160
# 2                                 True                NaN
# 3                                  NaN            16500.0
# 4                                  NaN              35000
# 5                                  NaN                788
# ..                                 ...                ...
# 477                               True                100
# 485                               True                 40
# 501                               True                NaN
# 374                               True                NaN
# 439                               True                 56
#
#     place.facilities.guide-dogs place.facilities.hearing-loop  \
# 0                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
# 5                           NaN                           NaN
# ..                          ...                           ...
# 477                         NaN                           NaN
# 485                         NaN                           NaN
# 501                         NaN                           NaN
# 374                         NaN                           NaN
# 439                         NaN                           NaN
#
#     place.child-friendly place.facilities.toilets.baby-changing
# 0                    NaN                                    NaN
# 2                    NaN                                    NaN
# 3                    NaN                                    NaN
# 4                    NaN                                    NaN
# 5                    NaN                                    NaN
# ..                   ...                                    ...
# 477                  NaN                                    NaN
# 485                  NaN                                    NaN
# 501                  NaN                                    NaN
# 374                  NaN                                    NaN
# 439                  NaN                                    NaN
#
# [538 rows x 13 columns]

# %%
df_place_prop.to_pickle(dataframes_final+"/df_places_properties")

# %% [markdown]
# ## 16. PLACE PHONE NUMBER

# %%
df_places_pn=df_places_total[['place_id','phone_numbers']]
df_places_pn=df_places_pn[df_places_pn['phone_numbers'].notna()]
df_places_pn=pd.concat([df_places_pn.drop(['phone_numbers'], axis=1), df_places_pn['phone_numbers'].apply(pd.Series)], axis=1)

df_places_pn
# Out:
#      place_id           info     box_office
# 0           1  0131 558 7272  0131 558 7272
# 1         371  0131 346 1405            NaN
# 2         372  0131 285 6030            NaN
# 3         375  0131 661 5351            NaN
# 4         376            NaN  0131 335 6200
# ..        ...            ...            ...
# 439    101921  0131 313 4404            NaN
# 440    103236   01450 360400            NaN
# 505    126723   01835 830271            NaN
# 512    127508  07584 837 445            NaN
# 515    128007  0131 445 8600            NaN
#
# [1369 rows x 3 columns]

# %%
df_places_pn.to_pickle(dataframes_final+"/df_places_pn")

# %% [markdown]
# ## 17. PLACE LOCATION DATAFRAME

# %%
df_places_loc=df_places_total[['place_id','loc']]
df_places_loc=df_places_loc[df_places_loc['loc'].notna()]
df_places_loc=pd.concat([df_places_loc.drop(['loc'], axis=1), df_places_loc['loc'].apply(pd.Series)], axis=1)

df_places_loc
# Out:
#      place_id            latitude            longitude
# 0           1  55.955806109395006  -3.1923184844646357
# 1         371         55.94255035          -3.22056693
# 2         372   55.94930633508542   -3.192111771011355
# 3         375         55.95640000          -3.15627000
# 4         376         55.94067800          -3.36880500
# ..        ...                 ...                  ...
# 512    127508   56.12694697199462   -3.281544714233391
# 514    127985         55.95418700          -3.19310200
# 515    128007         55.85879500          -3.20775100
# 516    128231         55.98810000          -2.77096100
# 517    128392   55.85901877324268   -3.200228929885869
#
# [2473 rows x 3 columns]

# %%
df_places_loc.to_pickle(dataframes_final+"/df_places_loc")

# %% [markdown]
# ## 18. PLACES DESCRIPTION

# %%
df_places_desc=df_places_total[['place_id','descriptions']].explode('descriptions')
df_places_desc=df_places_desc[df_places_desc['descriptions'].notna()]
df_places_desc=pd.concat([df_places_desc.drop(['descriptions'], axis=1), df_places_desc['descriptions'].apply(pd.Series)], axis=1)

df_places_desc
# Out:
#      place_id                      type  \
# 0           1  description.list.default
# 1         371  description.list.default
# 2         372  description.list.default
# 4         376  description.list.default
# 5         377  description.list.default
# ..        ...                       ...
# 501    129920      description.official
# 529    130974      description.official
# 439    101921  description.list.default
# 439    101921      description.official
# 440    103236      description.official
#
#                                            description
# 0    Cheerful cavern with all the ingredients requi...
# 1    The St Brides Community Centre is a former chu...
# 2    The Institut Francais d'Ecosse in Edinburgh's ...
# 4    A popular large-scale events venue, the Royal ...
# 5    One of Edinburgh's largest, multi-use venues, ...
# ..                                                 ...
# 501  The purpose built cabaret venue for the Ladybo...
# 529  For more info about the exhibition head to @bl...
# 439  This Dalry stalwart continues to deliver creat...
# 439  First Coast is quality neighbourhood bistro na...
# 440  The Mansfield House Hotel is a substantial 19t...
#
# [689 rows x 3 columns]

# %%
# un-comment this line if you want to save the df_p_properties into a file
df_places_desc.to_pickle(dataframes_final+"/df_places_description")

# %% [markdown]
# ## 19. PLACES TAGS

# %%
df_places_tags=df_places_total[['place_id','tags']].explode('tags')
df_places_tags
# Out:
#      place_id             tags
# 0           1   Bar & pub food
# 0           1           Comedy
# 0           1      Restaurants
# 0           1           Venues
# 1         371          Cinemas
# ..        ...              ...
# 515    128007  Business centre
# 516    128231             Farm
# 516    128231         Outdoors
# 517    128392      Pubs & bars
# 517    128392      Restaurants
#
# [5971 rows x 2 columns]

# %%
df_places_tags=df_places_tags[df_places_tags['tags'].notna()]

# %%
df_places_tags.to_pickle(dataframes_final+"/df_places_tags")

# %%
df_places_tags
# Out:
#      place_id             tags
# 0           1   Bar & pub food
# 0           1           Comedy
# 0           1      Restaurants
# 0           1           Venues
# 1         371          Cinemas
# ..        ...              ...
# 515    128007  Business centre
# 516    128231             Farm
# 516    128231         Outdoors
# 517    128392      Pubs & bars
# 517    128392      Restaurants
#
# [5801 rows x 2 columns]

# %% [markdown]
# # SPARQL Vereification Data Set

# %%
CheckData=df_schedules.merge(df_places,on=['place_id','place_id'])

# %%
CheckData=CheckData.merge(df_e_tags,on=['event_id'])

# %%
CheckData=CheckData.merge(df_e_category,on=['event_id'])

# %%
Edinburgh=CheckData[CheckData['town']=='Edinburgh']

# %%
tem=Edinburgh.loc[Edinburgh['tags']=='Music']

# %%
tem[tem['category']=='Music']
# Out:
#         event_id                   start_ts                     end_ts  \
# 1         157884  2018-04-26T20:00:00+01:00  2018-04-26T20:00:00+01:00
# 10        160228  2018-11-23T20:00:00+00:00  2018-11-23T20:00:00+00:00
# 26        178122  2018-03-23T19:00:00+00:00  2018-03-23T19:00:00+00:00
# 28        178122  2020-04-10T19:00:00+01:00  2020-04-10T19:00:00+01:00
# 30        178122  2019-04-19T19:00:00+01:00  2019-04-19T19:00:00+01:00
# ...          ...                        ...                        ...
# 135238   1680449  2021-08-26T20:30:00+01:00  2021-08-26T20:30:00+01:00
# 135239   1680450  2021-08-17T20:30:00+01:00  2021-08-17T20:30:00+01:00
# 135240   1680455  2021-08-09T20:30:00+01:00  2021-08-09T20:30:00+01:00
# 135290   1691538  2021-08-25T21:00:00+01:00  2021-08-26T21:00:00+01:00
# 135353   1672067  2021-09-25T18:00:00+01:00  2021-09-25T20:00:00+01:00
#
#         place_id performance_space            created_ts  \
# 1            383               NaN  2020-01-24T12:59:18Z
# 10           383               NaN  2020-01-24T12:59:18Z
# 26           383               NaN  2020-01-24T12:59:18Z
# 28           383               NaN  2020-01-24T12:59:18Z
# 30           383               NaN  2020-01-24T12:59:18Z
# ...          ...               ...                   ...
# 135238    129818               NaN  2021-06-28T10:55:23Z
# 135239    129818               NaN  2021-06-28T10:55:23Z
# 135240    129818               NaN  2021-06-28T10:55:23Z
# 135290    130151        Main Stage  2021-07-21T15:46:15Z
# 135353    130868               NaN  2021-09-21T14:22:41Z
#
#                  modified_ts                           name  \
# 1       2020-01-24T12:59:18Z               The Queen's Hall
# 10      2020-01-24T12:59:18Z               The Queen's Hall
# 26      2020-01-24T12:59:18Z               The Queen's Hall
# 28      2020-01-24T12:59:18Z               The Queen's Hall
# 30      2020-01-24T12:59:18Z               The Queen's Hall
# ...                      ...                            ...
# 135238  2021-06-28T10:55:23Z  Edinburgh Park Festival Venue
# 135239  2021-06-28T10:55:23Z  Edinburgh Park Festival Venue
# 135240  2021-06-28T10:55:23Z  Edinburgh Park Festival Venue
# 135290  2021-07-21T15:46:15Z   NCP Edinburgh Castle Terrace
# 135353  2021-09-21T14:22:41Z                St Celia's Hall
#
#                             sort_name              address       town  \
# 1                        Queen's Hall  85--89 Clerk Street  Edinburgh
# 10                       Queen's Hall  85--89 Clerk Street  Edinburgh
# 26                       Queen's Hall  85--89 Clerk Street  Edinburgh
# 28                       Queen's Hall  85--89 Clerk Street  Edinburgh
# 30                       Queen's Hall  85--89 Clerk Street  Edinburgh
# ...                               ...                  ...        ...
# 135238  Edinburgh Park Festival Venue         Lochside Way  Edinburgh
# 135239  Edinburgh Park Festival Venue         Lochside Way  Edinburgh
# 135240  Edinburgh Park Festival Venue         Lochside Way  Edinburgh
# 135290   NCP Edinburgh Castle Terrace       Castle Terrace  Edinburgh
# 135353                St Celia's Hall     50 Niddry Street  Edinburgh
#
#        postal_code country_code                                      website  \
# 1          EH8 9JG           GB                 http://www.thequeenshall.net
# 10         EH8 9JG           GB                 http://www.thequeenshall.net
# 26         EH8 9JG           GB                 http://www.thequeenshall.net
# 28         EH8 9JG           GB                 http://www.thequeenshall.net
# 30         EH8 9JG           GB                 http://www.thequeenshall.net
# ...            ...          ...                                          ...
# 135238    EH12 9GG           GB  https://www.eif.co.uk/venues/edinburgh-park
# 135239    EH12 9GG           GB  https://www.eif.co.uk/venues/edinburgh-park
# 135240    EH12 9GG           GB  https://www.eif.co.uk/venues/edinburgh-park
# 135290     EH1 2EW           GB                                          NaN
# 135353     EH1 1LG           GB             https://www.stcecilias.ed.ac.uk/
#
#                                     email status   tags category
# 1       boxoffice@queenshalledinburgh.org   live  Music    Music
# 10      boxoffice@queenshalledinburgh.org   live  Music    Music
# 26      boxoffice@queenshalledinburgh.org   live  Music    Music
# 28      boxoffice@queenshalledinburgh.org   live  Music    Music
# 30      boxoffice@queenshalledinburgh.org   live  Music    Music
# ...                                   ...    ...    ...      ...
# 135238                                NaN   live  Music    Music
# 135239                                NaN   live  Music    Music
# 135240                                NaN   live  Music    Music
# 135290                                NaN   live  Music    Music
# 135353            stceciliashall@ed.ac.uk   live  Music    Music
#
# [7698 rows x 18 columns]

# %%
def dataframe_groupby_size(df, column_list, rename, level=None, city=None, period="full"):
    if len(column_list)==1:
        column=column_list[0]
        df_v1=df.groupby([column]).size().reset_index()
        df_v1=df_v1.rename(columns={0: rename}).sort_values(by=[rename], ascending=False)
        if city:
            title= level+" " + rename+ " per "+ column + " at " +city
            if period!= "full":
                title = title + " for the month of " + month_string + " over the years"
            fig_scatter=px.scatter(df_v1, x=column,y=rename, color=rename, size=rename, size_max=50, title=title)
            fig_bar= px.bar(df_v1, x=column, y=rename, color=column, barmode='group', title=title)
            
           
        else:
            title= level+" " + rename+ " per "+ column 
            if period != "full":
                title = title + " for the month of " + month_string + " over the years"
            fig_scatter=px.scatter(df_v1, x=column,y=rename, color=rename, size=rename, size_max=50, title=title)
            fig_bar= px.bar(df_v1, x=column, y=rename, color=column, barmode='group', title=title)
            

        return df_v1, fig_scatter, fig_bar
    else:
        df_v1=df.groupby(column_list).size().reset_index()
        df_v1=df_v1.rename(columns={0: rename})
        return df_v1

# %%
g_tags=dataframe_groupby_size(tem, ['tags','category'], 'frequency', 'Events')

# %%
g_tags
# Out:
#      tags          category  frequency
# 0   Music             Books         92
# 1   Music             Clubs        257
# 2   Music            Comedy         81
# 3   Music             Dance        233
# 4   Music          Days out        337
# 5   Music              Film        358
# 6   Music              Kids         75
# 7   Music              LGBT         21
# 8   Music             Music       7698
# 9   Music  Talks & Lectures          3
# 10  Music           Theatre         70
# 11  Music        Visual art          1
